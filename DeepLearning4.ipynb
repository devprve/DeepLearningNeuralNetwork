# %% [markdown]
# Write  a colab pytorch classes based - 3 layer deep neural network for non linear regression using pytorch builtin functionality of modules etc.,. backprop etc.,.

# %% [markdown]
# #Import necessary libraries

# %%
import torch
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.manifold import TSNE
from sklearn.metrics import mean_squared_error

# %% [markdown]
# #Data

# %%
def get_true_labels(X, weights_true, bias_true):
  return (-3 * X ** 2) @ weights_true.T + X @ weights_true.T + bias_true.T

# %%
n_samples = 250
input_dim = 3
output_dim = 2

torch.manual_seed(123)
max = 1
min = -1
X = (max - min) * torch.rand((n_samples, input_dim)) + min
print('Sample X: ' + str(X[:2]))

weights_true = torch.tensor([[5., 1., -10.], [-2., -6., 1.]])
bias_true = torch.tensor([[1.], [1.]])

y_true = get_true_labels(X, weights_true, bias_true)
print('Sample y: ' + str(y_true[:2]))
# Out:
# Sample X: tensor([[-0.4078,  0.0331, -0.4967],
#         [ 0.3771, -0.8521,  0.7330]])
# Sample y: tensor([[ 8.8634,  1.3976],
#         [ 6.5125, 18.4003]])

# %% [markdown]
# #Plot 3D

# %%
def plot_3d(title, X, y, y_pred=None):
  X_tnse = TSNE(n_components=2, random_state=123).fit_transform(X)

  fig = plt.figure()
  ax = fig.add_subplot(111, projection='3d')
  ax.scatter(X_tnse[:,0], X_tnse[:,1], y, label='y_true')
  ax.set_title(title)
  if y_pred is not None:
    ax.scatter(X_tnse[:,0], X_tnse[:,1], y_pred, label='y_pred', marker='v')
  plt.legend()
  plt.show()

# %%
plot_3d('Output 1', X, y_true[:,0])
plot_3d('Output 2', X, y_true[:,1])

# %% [markdown]
# #Build Neural Network

# %%
# Mean Squared Error class to compute error and gradient
class MSE:
  def __init__(self, y_pred, y_true):
    self.y_pred = y_pred
    self.y_true = y_true
  
  # Compute the mean squared error
  def get_error(self):
    n = self.y_true.shape[0]
    return ((self.y_pred - self.y_true) ** 2) / n
  
  # Compute the gradient of the mean squared error w.r.t. the predicted output
  def backward(self):
    n = self.y_true.shape[0]
    self.gradient = 2.0 * (self.y_pred - self.y_true) / n
    return self.gradient

# Layer class to represent a single layer in the neural network
class Layer:
  def __init__(self, num_input_nodes=1, num_output_nodes=1, activation=None):
    self.num_input_nodes = num_input_nodes
    self.num_output_nodes = num_output_nodes
    self.weights = torch.rand((num_input_nodes, num_output_nodes), requires_grad=True)
    self.bias = torch.rand((1), requires_grad=True)
    self.X = torch.ones((num_input_nodes))
    # Set activation function
    if activation == 'relu':
      self.activation = Relu()
    else: 
      self.activation = None
  
  # Forward pass through the layer
  def forward(self, X):
    self.X = X
    self.Z = self.X @ self.weights + self.bias
    self.weights.retain_grad()
    self.bias.retain_grad()
    # Pass output to activation function if one is specified
    if self.activation == None:
      return self.Z 
    else:
      return self.activation.forward(self.Z)

  # Backward pass through the layer to compute gradients
  def backward(self):
    self.dJdW = self.weights.grad
    self.dJdb = self.bias.grad

  # Update weight and bias params with learning rate step size
  def update(self, lr):
    self.weights = self.weights - lr * self.dJdW
    self.bias = self.bias - lr * self.dJdb

  def __str__(self):
    return 'Layer: ({},{}) Activation Function: {}\nInputs:\n{}\nWeights:\n{}\nBias:{}'.format(self.num_input_nodes, self.num_output_nodes, self.activation, self.X, self.weights, self.bias)

# ReLU activation function
class Relu:
  def __init__(self):
    self.input = torch.tensor([])

  # Forward pass through the ReLU function
  def forward(self, input):
    self.input = input
    self.output = torch.clamp(self.input, min=0)
    return self.output
  
  # No explicit backward pass needed for ReLU function since autodifferentiation takes care of this
  def backward(self, upstream_gradient):
    return
  
  # No update needed to ReLU members
  def update(self, lr):
    return

  def __str__(self):
    return 'ReLU'

class NeuralNet:
  def __init__(self, num_inputs=3, num_hidden=[2], num_outputs=2, activation=None):
    # Initialize the number of inputs, hidden layers, and outputs for the network
    self.num_inputs = num_inputs
    self.num_hidden = num_hidden
    self.num_outputs = num_outputs

    # Define the layers for the network
    layers = [self.num_inputs] + self.num_hidden + [self.num_outputs]
    
    self.layers = []
    for i in range(len(layers[:-1])):
      # Add activation function to all layers except for the last layer, which is for regression
      if i == len(layers[:-1]) - 1:
        self.layers.append(Layer(layers[i], layers[i + 1], activation=None))
      else:
        self.layers.append(Layer(layers[i], layers[i + 1], activation))

    # Print network architecture for debugging
    print('Neural Net Architecture:')
    for i, layer in enumerate(self.layers):
      print('=== Layer {} ==='.format(i))
      print(layer)
    print()

  def forward(self, inputs):
    # Pass the input through each layer of the network
    curr_out = inputs
    for l in self.layers:
      curr_out = l.forward(curr_out)

    return curr_out
  
  def backward(self, y_pred, y_true):
    # Compute the error and backpropagate it through the network
    external_grad = torch.ones(y_true.shape)

    mse = MSE(y_pred, y_true)
    error = mse.get_error()
    print('Error: ', mean_squared_error(y_true, y_pred.detach().numpy()))
    error.backward(gradient=external_grad, retain_graph=True)

    for layer in reversed(self.layers):
      layer.backward()
    
  def update(self, lr):
    # Update the weights and biases of each layer in the network
    for layer in self.layers:
      layer.update(lr)
  
  # Training loop over # of epochs
  def fit(self, X, y_true, epochs):
    # Train the network for a given number of epochs
    for i in range(epochs):
      y_pred = self.forward(X)
      self.backward(y_pred, y_true) 
      self.update(lr)

  def __str__(self):
    # Return a string representation of the network
    s = [str(layer) for layer in self.layers]
    return '\n'.join(s)

# %% [markdown]
# #Hyperparameters

# %%
epochs = 400
lr = 0.01

n_inputs = X.shape[1]
n_outputs = y_true.shape[1]

# %% [markdown]
# #Train neural network with ReLU activation

# %%
nn = NeuralNet(num_inputs=n_inputs, num_hidden=[4, 3], num_outputs=n_outputs, activation='relu')
nn.fit(X, y_true, epochs)
y_pred = nn.forward(X).detach().numpy()

err = mean_squared_error(y_true, y_pred)
print('Final Error: {}'.format(err))
# Out:
# Neural Net Architecture:
# === Layer 0 ===
# Layer: (3,4) Activation Function: ReLU
# Inputs:
# tensor([1., 1., 1.])
# Weights:
# tensor([[0.3027, 0.7200, 0.0670, 0.6579],
#         [0.0233, 0.4404, 0.6203, 0.4648],
#         [0.7944, 0.8952, 0.1405, 0.8582]], requires_grad=True)
# Bias:tensor([0.1465], requires_grad=True)
# === Layer 1 ===
# Layer: (4,3) Activation Function: ReLU
# Inputs:
# tensor([1., 1., 1., 1.])
# Weights:
# tensor([[0.1765, 0.4007, 0.9541],
#         [0.8567, 0.4604, 0.2238],
#         [0.3047, 0.3019, 0.7772],
#         [0.4963, 0.3846, 0.0948]], requires_grad=True)
# Bias:tensor([0.5410], requires_grad=True)
# === Layer 2 ===
# Layer: (3,2) Activation Function: None
# Inputs:
# tensor([1., 1., 1.])
# Weights:
# tensor([[0.8090, 0.8157],
#         [0.5431, 0.9595],
#         [0.3764, 0.8885]], requires_grad=True)
# Bias:tensor([0.7794], requires_grad=True)
#
# Error:  102.44331
# Error:  96.46058
# Error:  93.4281
# Error:  90.94411
# Error:  88.831055
# Error:  87.154816
# Error:  85.938644
# Error:  85.07471
# Error:  84.50282
# Error:  84.154076
# Error:  83.941795
# Error:  83.79701
# Error:  83.68406
# Error:  83.588806
# Error:  83.50547
# Error:  83.427475
# Error:  83.35094
# Error:  83.276665
# Error:  83.20305
# Error:  83.12921
# Error:  83.05541
# Error:  82.98004
# Error:  82.900764
# Error:  82.82167
# Error:  82.74131
# Error:  82.658775
# Error:  82.57085
# Error:  82.48302
# Error:  82.39529
# Error:  82.30705
# Error:  82.216354
# Error:  82.12436
# Error:  82.031044
# Error:  81.93596
# Error:  81.833115
# Error:  81.728
# Error:  81.617516
# Error:  81.497116
# Error:  81.37567
# Error:  81.23535
# Error:  81.06122
# Error:  80.85882
# Error:  80.656784
# Error:  80.43774
# Error:  80.17909
# Error:  79.75026
# Error:  79.05604
# Error:  77.86023
# Error:  76.20651
# Error:  74.41209
# Error:  72.605576
# Error:  70.8488
# Error:  69.20133
# Error:  67.659454
# Error:  66.18434
# Error:  64.76936
# Error:  63.410614
# Error:  62.08651
# Error:  60.780846
# Error:  59.4759
# Error:  58.156845
# Error:  56.81334
# Error:  55.411064
# Error:  53.92756
# Error:  52.34838
# Error:  50.66703
# Error:  48.873386
# Error:  47.081047
# Error:  45.47216
# Error:  44.02311
# Error:  42.98066
# Error:  42.46067
# Error:  44.19831
# Error:  46.312267
# Error:  60.7317
# Error:  46.123695
# Error:  58.396255
# Error:  39.850452
# Error:  42.84839
# Error:  37.952686
# Error:  40.360004
# Error:  36.069866
# Error:  37.58832
# Error:  34.510284
# Error:  35.69504
# Error:  33.30507
# Error:  34.51527
# Error:  32.431885
# Error:  33.853092
# Error:  31.852676
# Error:  33.191814
# Error:  31.259285
# Error:  33.01083
# Error:  30.966908
# Error:  32.680817
# Error:  30.448153
# Error:  32.195843
# Error:  29.71601
# Error:  31.45269
# Error:  29.089998
# Error:  30.829332
# Error:  28.70227
# Error:  30.528744
# Error:  28.14523
# Error:  29.99863
# Error:  27.67881
# Error:  29.695614
# Error:  27.299797
# Error:  29.550093
# Error:  27.011398
# Error:  29.271023
# Error:  26.512352
# Error:  28.569874
# Error:  26.062162
# Error:  28.045584
# Error:  25.581497
# Error:  27.480444
# Error:  25.181042
# Error:  27.066294
# Error:  24.927134
# Error:  26.814896
# Error:  24.569725
# Error:  26.422794
# Error:  24.246502
# Error:  26.036266
# Error:  23.922604
# Error:  25.678257
# Error:  23.630423
# Error:  25.366198
# Error:  23.39442
# Error:  25.13498
# Error:  23.170643
# Error:  24.907787
# Error:  22.965069
# Error:  24.625656
# Error:  22.647486
# Error:  24.12506
# Error:  22.359735
# Error:  23.810637
# Error:  22.206106
# Error:  23.73014
# Error:  22.115526
# Error:  23.734299
# Error:  21.86252
# Error:  23.474619
# Error:  21.734825
# Error:  23.418518
# Error:  21.694014
# Error:  23.502497
# Error:  21.707521
# Error:  23.672531
# Error:  21.751352
# Error:  23.886086
# Error:  21.804817
# Error:  24.104748
# Error:  21.852068
# Error:  24.45287
# Error:  21.937937
# Error:  24.577103
# Error:  21.93114
# Error:  24.645033
# Error:  21.908058
# Error:  24.663849
# Error:  21.87063
# Error:  24.647142
# Error:  21.824032
# Error:  24.606232
# Error:  21.771822
# Error:  24.561213
# Error:  21.719955
# Error:  24.499939
# Error:  21.665323
# Error:  24.390272
# Error:  21.567636
# Error:  24.222382
# Error:  21.615833
# Error:  24.374138
# Error:  21.559454
# Error:  24.291376
# Error:  21.49975
# Error:  24.173145
# Error:  21.386532
# Error:  23.984161
# Error:  21.301899
# Error:  23.853558
# Error:  21.20678
# Error:  23.81305
# Error:  21.178095
# Error:  23.78049
# Error:  21.146751
# Error:  23.77507
# Error:  21.124287
# Error:  23.748524
# Error:  21.115757
# Error:  23.854649
# Error:  21.127876
# Error:  23.921234
# Error:  21.182003
# Error:  24.034885
# Error:  21.122513
# Error:  23.867214
# Error:  21.084848
# Error:  23.8877
# Error:  21.066444
# Error:  23.862938
# Error:  21.030617
# Error:  23.732986
# Error:  20.935152
# Error:  23.534004
# Error:  20.849611
# Error:  23.338974
# Error:  20.76437
# Error:  23.20094
# Error:  20.703964
# Error:  23.102161
# Error:  20.6568
# Error:  23.089394
# Error:  20.638435
# Error:  23.147686
# Error:  20.646605
# Error:  23.195751
# Error:  20.66962
# Error:  23.124454
# Error:  20.613476
# Error:  23.143827
# Error:  20.601946
# Error:  22.970665
# Error:  20.512012
# Error:  22.974564
# Error:  20.502619
# Error:  22.948845
# Error:  20.47454
# Error:  22.781307
# Error:  20.380898
# Error:  22.587177
# Error:  20.258461
# Error:  22.365519
# Error:  20.09808
# Error:  21.700073
# Error:  19.614302
# Error:  21.062569
# Error:  19.521393
# Error:  21.200039
# Error:  19.537636
# Error:  21.12679
# Error:  19.63259
# Error:  21.43176
# Error:  19.769173
# Error:  21.668892
# Error:  19.860222
# Error:  21.75176
# Error:  19.850618
# Error:  21.641867
# Error:  19.751688
# Error:  21.482483
# Error:  19.671583
# Error:  21.359423
# Error:  19.58233
# Error:  21.095133
# Error:  19.450266
# Error:  20.951097
# Error:  19.385351
# Error:  20.828432
# Error:  19.31578
# Error:  20.868277
# Error:  19.346693
# Error:  20.821308
# Error:  19.310324
# Error:  20.78221
# Error:  19.289274
# Error:  20.76708
# Error:  19.283155
# Error:  20.762794
# Error:  19.280104
# Error:  20.755497
# Error:  19.273376
# Error:  20.724861
# Error:  19.368824
# Error:  20.90948
# Error:  19.406685
# Error:  21.026562
# Error:  19.452757
# Error:  20.989605
# Error:  19.386557
# Error:  20.763588
# Error:  19.23962
# Error:  20.552532
# Error:  19.182579
# Error:  20.424553
# Error:  19.135702
# Error:  20.32568
# Error:  19.073647
# Error:  20.25587
# Error:  19.008743
# Error:  20.185272
# Error:  18.97966
# Error:  20.111153
# Error:  19.018433
# Error:  20.266808
# Error:  19.113722
# Error:  20.411617
# Error:  19.228632
# Error:  20.567938
# Error:  19.293951
# Error:  20.711475
# Error:  19.346107
# Error:  20.63466
# Error:  19.239714
# Error:  20.462486
# Error:  19.124693
# Error:  20.283508
# Error:  18.98722
# Error:  20.092594
# Error:  18.953915
# Error:  20.056648
# Error:  18.933966
# Error:  20.047686
# Error:  18.934402
# Error:  20.066677
# Error:  18.947989
# Error:  20.096405
# Error:  18.965916
# Error:  20.166569
# Error:  19.003172
# Error:  20.225292
# Error:  19.030836
# Error:  20.27154
# Error:  19.05079
# Error:  20.303015
# Error:  19.087234
# Error:  20.353306
# Error:  19.08025
# Error:  20.336597
# Error:  19.067753
# Error:  20.313972
# Error:  19.077492
# Error:  20.321878
# Error:  19.05013
# Error:  20.31889
# Error:  19.07077
# Error:  20.349712
# Error:  19.052563
# Error:  20.32576
# Error:  19.034977
# Error:  20.30488
# Error:  19.019138
# Error:  20.288538
# Error:  19.00591
# Error:  20.293041
# Error:  19.028954
# Error:  20.328228
# Error:  19.038795
# Error:  20.34626
# Error:  19.040197
# Error:  20.424868
# Error:  19.017006
# Error:  20.337727
# Error:  18.96899
# Error:  20.126333
# Error:  18.843159
# Error:  20.058216
# Error:  18.818558
# Error:  19.896046
# Error:  18.78239
# Error:  19.829763
# Error:  18.753933
# Error:  19.955318
# Error:  18.821877
# Error:  19.933992
# Error:  18.75517
# Error:  19.785152
# Error:  18.788374
# Error:  19.97953
# Error:  18.830982
# Error:  19.832306
# Error:  18.743382
# Error:  19.739765
# Error:  18.694786
# Error:  19.675089
# Error:  18.659794
# Error:  19.64189
# Error:  18.693869
# Error:  19.690151
# Error:  18.657644
# Error:  19.658249
# Error:  18.669844
# Error:  19.810444
# Error:  18.63622
# Error:  19.661995
# Error:  18.606297
# Error:  19.613491
# Error:  18.523684
# Error:  19.50127
# Error:  18.47062
# Error:  19.477892
# Error:  18.51428
# Error:  19.507174
# Error:  18.52786
# Error:  19.55402
# Error:  18.550749
# Final Error: 19.519275665283203

# %%
plot_3d('With ReLU Output for y1', X, y_true[:,0], y_pred[:,0])
plot_3d('With ReLU Output for y2', X, y_true[:,1], y_pred[:,1])
